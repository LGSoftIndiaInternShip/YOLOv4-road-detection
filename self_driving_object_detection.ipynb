# %%
# clone darknet repo
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15530, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15530 (delta 5), reused 13 (delta 4), pack-reused 15514
# Receiving objects: 100% (15530/15530), 14.22 MiB | 13.33 MiB/s, done.
# Resolving deltas: 100% (10417/10417), done.

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# Out:
# [Errno 2] No such file or directory: 'darknet'
# /content/darknet

# %%
# make darknet (builds darknet so that you can then use the darknet.py file and have its dependencies)
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ...

# %%
#!wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/LGSoftIndiaInternShip/self-driving-object-detection.git
# Out:
# Cloning into 'self-driving-object-detection'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 16 (delta 4), reused 10 (delta 3), pack-reused 0
# Unpacking objects: 100% (16/16), 146.31 KiB | 1.51 MiB/s, done.

# %%
# !cp self-driving-object-detection/obj* darknet/data
# !cp self-driving-object-detection/yolo-obj.cfg darknet

# %%
# !gdown https://drive.google.com/uc?id=1Aqj_gFSDrQKm7z8-U8Rjkl1k-Il-JQEC
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Aqj_gFSDrQKm7z8-U8Rjkl1k-Il-JQEC
# To: /content/data.zip
# 100% 1.06G/1.06G [00:21<00:00, 49.0MB/s]

# %%
# !unzip -u data.zip -d darknet
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: darknet/data/obj/1479505846969326795.txt
#   inflating: darknet/data/obj/1479505847469397760.jpg
#   inflating: darknet/data/obj/1479505847469397760.txt
#   inflating: darknet/data/obj/1479505848469345308.jpg
#   inflating: darknet/data/obj/1479505848469345308.txt
#   inflating: darknet/data/obj/1479505848969547095.jpg
#   inflating: darknet/data/obj/1479505848969547095.txt
#   inflating: darknet/data/obj/1479505849969319576.jpg
#   inflating: darknet/data/obj/1479505849969319576.txt
#   inflating: darknet/data/obj/1479505850469662423.jpg
#   inflating: darknet/data/obj/1479505850469662423.txt
#   inflating: darknet/data/obj/1479505851455286642.jpg
#   inflating: darknet/data/obj/1479505851455286642.txt
#   inflating: darknet/data/obj/1479505851971563779.jpg
#   inflating: darknet/data/obj/1479505851971563779.txt
#   inflating: darknet/data/obj/1479505852960765794.jpg
#   inflating: darknet/data/obj/1479505852960765794.txt
# ...

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
#!./darknet detector train data/obj.data yolo-obj.cfg yolov4.conv.137 -dont_show -map

# %%
# !gdown https://drive.google.com/uc?id=1TZ3auyez0jxyXQPdNKyBGHlN4xRwAuT4
# !mv yolo-obj_last.weights /content/drive/MyDrive/backup/

# %%
# !./darknet detector train data/obj.data yolo-obj.cfg /content/drive/MyDrive/backup/yolo-obj_last.weights -dont_show -map
# Out:
# ./darknet: error while loading shared libraries: libcuda.so.1: cannot open shared object file: No such file or directory

# %%
import cv2
import matplotlib.pyplot as plt

def imShow(path):
    image = cv2.imread(path)
    height, width = image.shape[:2]
    resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

    fig = plt.gcf()
    fig.set_size_inches(18, 10)
    plt.axis("off")
    plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
imShow('chart.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-096d9cb64b19> in <cell line: 1>()
# ----> 1 imShow('chart.png')
#
# <ipython-input-21-c8c62a0efbbd> in imShow(path)
#       4 def imShow(path):
#       5   image = cv2.imread(path)
# ----> 6   height, width = image.shape[:2]
#       7   resized_image = cv2.resize(image, (3 * width, 3 * height), interpolation = cv2.INTER_CUBIC)
#       8
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# !sed -i 's/batch=64/batch=1/' yolo-obj.cfg
# !sed -i 's/subdivisions=16/subdivisions=1/' yolo-obj.cfg

# %%
# !sed -i 's/batch=1/batch=64/' yolo-obj.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' yolo-obj.cfg

# %%
# !cp /content/drive/MyDrive/DL/Video_source/test.mp4 /content/darknet

# %%
# !./darknet detector demo data/obj.data yolo-obj.cfg /content/drive/MyDrive/backup/yolo-obj_final.weights /content/drive/MyDrive/DL/Video_source/test.mp4 -out_filename /content/drive/MyDrive/DL/Video_source/test_output.mp4 -dont_show
# Out:
# ./darknet: error while loading shared libraries: libcuda.so.1: cannot open shared object file: No such file or directory

# %%
# !cp test_output.mp4 /content/drive/MyDrive/DL/Video_output

# %%
# !pwd
